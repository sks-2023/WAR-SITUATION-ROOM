# %% [markdown]
# ## Project: Write a Data Science Blog Post
# #### Business Understanding
# In this project, we are analyzing conflict events data in Sudan from 15 of April to 31 of may 2023. The goal is to gain insights into the types of conflict events, the regions most affected by the conflict, and to predict the likelihood of civilian casualties based on the conflict type, region, and time of day.
# This script reads in a dataset of conflict events in Sudan from 15 of April to 31 of may 2023, and trying to answer the following questions:
# 1. what is the total fatalities caused by each conflicit type? and number of fatalities in each region?
# 2. What are the main drivers of conflict in Sudan, according to the ACLED data? Are these drivers consistent across different regions of the country, or do they vary depending on local circumstances?
# 3. How has the conflict in Sudan evolved over the past two years, and what factors have contributed to these changes? Have there been any significant turning points or events that have influenced the trajectory of the conflict?
# 4. What is the impact of the conflict in Sudan on civilians, and how has this changed over time? Are there particular groups or regions of the country that are especially vulnerable to violence, and if so, why? What efforts have been made to protect civilians and mitigate the effects of the conflict?

# %% [markdown]
# ## data Understanding,
# Access and Explore

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# first step is loading data
cleaned_df = pd.read_csv('wardata.csv')

# %% [markdown]
# ### analyze data

# %% [markdown]
# what is the total fatalities caused by each conflicit type? and number of fatalities in each region?

# %%
# Group the data by event type and sum the fatalities
grouped_data = cleaned_df.groupby('event_type')['fatalities'].sum()

# %%
# Sort the data by the number of fatalities in descending order
sorted_data = grouped_data.sort_values(ascending=False)

# %%
# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Fatalities by Event Type')
plt.xlabel('Event Type')
plt.ylabel('Number of Fatalities')
plt.xticks(rotation=85)
# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')
plt.show()

# %%
# Group the data by event type and sum the fatalities
sub_event_type = cleaned_df.groupby('sub_event_type')['fatalities'].sum()
# Sort the data by the number of fatalities in descending order
sorted_data = sub_event_type.sort_values(ascending=False)

# %%
# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Fatalities by Sub Event Type')
plt.xlabel('Sub Event Type')
plt.ylabel('Number of Fatalities')
plt.xticks(rotation=85)
# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')
plt.show()

# %%
# Filter the data for the sub-event type 'Battles'
Battles_event_type = cleaned_df[cleaned_df['event_type'] == 'Battles']

# Group the data by event type and sum the fatalities
grouped_data = Battles_event_type.groupby(['sub_event_type'])['fatalities'].sum()

# Sort the data by the number of fatalities in descending order
sorted_data = grouped_data.sort_values(ascending=False)

# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Fatalities for Battles by Sub Event Type')
plt.xlabel('Sub-Event Type for Battles')
plt.ylabel('Number of Fatalities')
plt.xticks(rotation=75)

# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
# Group the data by states and sum the fatalities
State_grouped_data = cleaned_df.groupby(['admin1'])['fatalities'].sum()

# Sort the data by the number of fatalities in descending order
sorted_data = State_grouped_data.sort_values(ascending=False)

# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Fatalities   by State')
plt.xlabel('States')
plt.ylabel('Number of Fatalities')
plt.xticks(rotation=75)

# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
# Filter the data for the sub-event type 'Battles'
WD_State_data = cleaned_df[cleaned_df['admin1'] == 'West Darfur']

# Group the data by event type and sum the fatalities
grouped_data = WD_State_data.groupby(['admin2'])['fatalities'].sum()

# Sort the data by the number of fatalities in descending order
sorted_data = grouped_data.sort_values(ascending=False)

# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Fatalities by West Darfur localities')
plt.xlabel('Localities')
plt.ylabel('Number of Fatalities')
plt.xticks(rotation=75)

# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
# Filter the data for the sub-event type 'Battles'
khartoum_state_data = cleaned_df[cleaned_df['admin1'] == 'Khartoum']

# Group the data by event type and sum the fatalities
grouped_data = khartoum_state_data.groupby(['admin2'])['fatalities'].sum()

# Sort the data by the number of fatalities in descending order
sorted_data = grouped_data.sort_values(ascending=False)

# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Fatalities by Khartoum localities')
plt.xlabel('Localities')
plt.ylabel('Number of Fatalities')
plt.xticks(rotation=75)

# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
# Group the data by event type and sum the fatalities
grouped_data = cleaned_df.groupby('admin1')['event_type'].count()
# Sort the data by the number of fatalities in descending order
sorted_data = grouped_data.sort_values(ascending=False)

# %%
# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Events by State')
plt.xlabel('State')
plt.ylabel('Number of Events')
plt.xticks(rotation=55)
# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')
plt.show()

# %%
# Filter the data for admin1 = 'Khartoum'
filtered_data = cleaned_df[cleaned_df['admin1'] == 'Khartoum']

# Group the data by event type and count the occurrences
grouped_data = filtered_data.groupby('event_type').size()

# Sort the data by the number of occurrences in descending order
sorted_data = grouped_data.sort_values(ascending=False)

# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Events by Event Type in Khartoum')
plt.xlabel('Event Type')
plt.ylabel('Number of Events')
plt.xticks(rotation=15)

# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
# Filter the data for admin1 = 'Khartoum'
filtered_data = cleaned_df[cleaned_df['admin1'] == 'Khartoum']

# Group the data by event type and count the occurrences
grouped_data = filtered_data.groupby('sub_event_type').size()

# Sort the data by the number of occurrences in descending order
sorted_data = grouped_data.sort_values(ascending=False)

# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Events by Sub Event Type in Khartoum')
plt.xlabel('Event Type')
plt.ylabel('Number of Events')
plt.xticks(rotation=85)

# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
# Filter the data for admin1 = 'Khartoum'
filtered_data = cleaned_df[cleaned_df['admin1'] == 'Khartoum']

# Group the data by event type and count the occurrences
grouped_data = filtered_data.groupby('admin2').size()

# Sort the data by the number of occurrences in descending order
sorted_data = grouped_data.sort_values(ascending=False)

# Visualize the results using a bar chart
plt.figure(figsize=(10, 6))
ax = sorted_data.plot(kind='bar', color='blue')
plt.title('Number of Events by Event Type in Khartoum localites')
plt.xlabel('Localities')
plt.ylabel('Number of Events')
plt.xticks(rotation=15)

# Add data labels to the bars
for i, v in enumerate(sorted_data):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()
